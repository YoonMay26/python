# %%
import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
df1 = pd.read_csv('./data/GOMS2019.csv')
df1
# Out:
#        이직여부  majorcat  school  area  sex        age  graduy  a001  industry  \
# 0         2         1       1     8    1  21.750000    2018  2018         7
# 1         1         1       1     8    1  25.250000    2018  2018         7
# 2         2         1       1     8    1  24.500000    2018  2018         9
# 3         2         1       1    10    1  26.000000    2018  2018         3
# 4         2         1       1     1    2  25.083333    2017  2019         7
# ...     ...       ...     ...   ...  ...        ...     ...   ...       ...
# 11647     2         7       2     3    2  24.000000    2018  2018        16
# 11648     2         7       2     1    2  25.833333    2017  2018        15
# 11649     2         7       2     1    2  25.083333    2018  2018        16
# 11650     2         7       2     1    1  26.750000    2018  2019         7
# 11651     1         3       1     8    1  27.166667    2018  2018        16
#
# ...

# %%
df2 = pd.read_csv('./data/GOMS2019_columns.csv')
df2
# Out:
#       columns   desc                                              label
# 0    majorcat   전공계열                 인문1, 사회2, 교육3, 공학4, 자연5, 의약6, 예체능7
# 1      school   학교유형                           2~3년제(1), 4년제(2), 교육대(3)
# 2        area  학교소재지  서울1,부산2,대구3,대전4,인천5,광주6,울산7,경기8,강원9,충북10,충남11,...
# 3         sex     성별                                             남1, 여2
# 4         age     연령                                                NaN
# ..        ...    ...                                                ...
# 154       job      6                                 미용·여행·숙박·음식·경비·청소직
# 155       job      7                                       영업·판매·운전·운송직
# 156       job      8                                             건설·채굴직
# 157       job      9                                          설치·정비·생산직
# 158       job     10                                              농림어업직
#
# [159 rows x 3 columns]

# %% [markdown]
# ## 데이터 탐색

# %%
df1.columns
# Out:
# Index(['이직여부', 'majorcat', 'school', 'area', 'sex', 'age', 'graduy', 'a001',
#        'industry', 'job',
#        ...
#        'p039', 'p041', 'p043', 'p045', 'r023', 'r024', 'r025', 'r026', 'r027',
#        'wt'],
#       dtype='object', length=130)

# %%
df1.head()
# Out:
#    이직여부  majorcat  school  area  sex        age  graduy  a001  industry  job  \
# 0     2         1       1     8    1  21.750000    2018  2018         7    7
# 1     1         1       1     8    1  25.250000    2018  2018         7    1
# 2     2         1       1     8    1  24.500000    2018  2018         9    1
# 3     2         1       1    10    1  26.000000    2018  2018         3    7
# 4     2         1       1     1    2  25.083333    2017  2019         7    7
#
#    ...  p039  p041  p043  p045  r023  r024  r025  r026  r027         wt
# 0  ...  1008     2     2     6    30     0     0     0     1  20.945343
# 1  ...   540     2     2     3    60    10     0    10     1  19.420393
# 2  ...  1570     2     2     2    30     0     0     0     1  19.420393
# 3  ...  1560     2     1     2   150    35     0     0     1  11.549823
# 4  ...     0     2    -1     1   120    50     0     0     1  37.668984
#
# [5 rows x 130 columns]

# %%
df1.tail()
# Out:
#        이직여부  majorcat  school  area  sex        age  graduy  a001  industry  \
# 11647     2         7       2     3    2  24.000000    2018  2018        16
# 11648     2         7       2     1    2  25.833333    2017  2018        15
# 11649     2         7       2     1    2  25.083333    2018  2018        16
# 11650     2         7       2     1    1  26.750000    2018  2019         7
# 11651     1         3       1     8    1  27.166667    2018  2018        16
#
#        job  ...  p039  p041  p043  p045  r023  r024  r025  r026  r027  \
# 11647    3  ...  1440     2     2     1    50     0     0     0     1
# 11648    1  ...  1600     2     2     1    40     0     0     0     1
# 11649    3  ...  1500     2     1     1    70     0     0     0     1
# 11650    7  ...  2000     2     2     2   100     9     0     0     1
# 11651    3  ...   810     2     2     6    40    50     0   100     2
#
#               wt
# 11647  45.471141
# 11648  19.295745
# 11649  31.941780
# ...

# %% [markdown]
# ## 데이터 전처리

# %%
# 관련 변수별로 슬라이싱 #기본인구통계

df1_person = df1[['이직여부','sex','age','graduy','job','industry']]
df1_person
# Out:
#        이직여부  sex        age  graduy  job  industry
# 0         2    1  21.750000    2018    7         7
# 1         1    1  25.250000    2018    1         7
# 2         2    1  24.500000    2018    1         9
# 3         2    1  26.000000    2018    7         3
# 4         2    2  25.083333    2017    7         7
# ...     ...  ...        ...     ...  ...       ...
# 11647     2    2  24.000000    2018    3        16
# 11648     2    2  25.833333    2017    1        15
# 11649     2    2  25.083333    2018    3        16
# 11650     2    1  26.750000    2018    7         7
# 11651     1    1  27.166667    2018    3        16
#
# [11652 rows x 6 columns]

# %%
# 관련 변수별로 슬라이싱 #교육 및 전공 관련 변수

df1_edu = df1[['이직여부','majorcat', 'school','area','job','industry']]
df1_edu
# Out:
#        이직여부  majorcat  school  area  job  industry
# 0         2         1       1     8    7         7
# 1         1         1       1     8    1         7
# 2         2         1       1     8    1         9
# 3         2         1       1    10    7         3
# 4         2         1       1     1    7         7
# ...     ...       ...     ...   ...  ...       ...
# 11647     2         7       2     3    3        16
# 11648     2         7       2     1    1        15
# 11649     2         7       2     1    3        16
# 11650     2         7       2     1    7         7
# 11651     1         3       1     8    3        16
#
# [11652 rows x 6 columns]

# %% [markdown]
# ### 결측치 확인

# %%
df1.isnull().sum()
# Out:
# 이직여부        0
# majorcat    0
# school      0
# area        0
# sex         0
#            ..
# r024        0
# r025        0
# r026        0
# r027        0
# wt          0
# Length: 130, dtype: int64

# %%
df1[df1.isnull()]
# Out:
#        이직여부  majorcat  school  area  sex  age  graduy  a001  industry  job  \
# 0       NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 1       NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 2       NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 3       NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 4       NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# ...     ...       ...     ...   ...  ...  ...     ...   ...       ...  ...
# 11647   NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 11648   NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 11649   NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 11650   NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
# 11651   NaN       NaN     NaN   NaN  NaN  NaN     NaN   NaN       NaN  NaN
#
#        ...  p039  p041  p043  p045  r023  r024  r025  r026  r027  wt
# ...

# %%
# null 컬럼 확인
null_cols = (df1 == -1).sum()
null_cols
# Out:
# 이직여부        0
# majorcat    0
# school      0
# area        0
# sex         0
#            ..
# r024        1
# r025        0
# r026        0
# r027        1
# wt          0
# Length: 130, dtype: int64

# %%
# 수치형 데이터 리스트
numeric_columns_list = [
    'age', 'a116', 'a117', 'a118', 'a119', 'a122', 'a125', 'f074',
    'f079', 'f080', 'f081', 'f082', 'f083', 'f084', 'j021', 'p017',
    'p039', 'r023', 'r024', 'r025', 'r026'
]

# -1 값의 합계를 계산
null_cols = (df1 == -1).sum()

# 수치형 데이터 리스트에 해당하는 컬럼 필터링 후 출력
for col in null_cols.index:
    if col in numeric_columns_list:
        print(f"{col}: {null_cols[col]}")
# Out:
# age: 0
# a116: 0
# a117: 0
# a118: 0
# a119: 0
# a122: 38
# a125: 37
# f074: 0
# f079: 0
# f080: 0
# f081: 0
# f082: 0
# f083: 0
# f084: 0
# j021: 14
# p017: 0
# p039: 19
# r023: 3
# r024: 1
# r025: 0
# r026: 0

# %%
df1_cleaned = df1[~df1[numeric_columns_list].eq(-1).any(axis=1)]

# -1 값 검토
df1_cleaned_null = (df1_cleaned == -1).sum()

for col in df1_cleaned_null.index:
    if col in numeric_columns_list:
        print(f"{col}: {df1_cleaned_null[col]}")
# Out:
# age: 0
# a116: 0
# a117: 0
# a118: 0
# a119: 0
# a122: 0
# a125: 0
# f074: 0
# f079: 0
# f080: 0
# f081: 0
# f082: 0
# f083: 0
# f084: 0
# j021: 0
# p017: 0
# p039: 0
# r023: 0
# r024: 0
# r025: 0
# r026: 0

# %%
df1_cleaned
# Out:
#        이직여부  majorcat  school  area  sex        age  graduy  a001  industry  \
# 0         2         1       1     8    1  21.750000    2018  2018         7
# 1         1         1       1     8    1  25.250000    2018  2018         7
# 2         2         1       1     8    1  24.500000    2018  2018         9
# 3         2         1       1    10    1  26.000000    2018  2018         3
# 4         2         1       1     1    2  25.083333    2017  2019         7
# ...     ...       ...     ...   ...  ...        ...     ...   ...       ...
# 11647     2         7       2     3    2  24.000000    2018  2018        16
# 11648     2         7       2     1    2  25.833333    2017  2018        15
# 11649     2         7       2     1    2  25.083333    2018  2018        16
# 11650     2         7       2     1    1  26.750000    2018  2019         7
# 11651     1         3       1     8    1  27.166667    2018  2018        16
#
# ...

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# ## 1. 이직 여부에 따른 취업 특성 분석

# %%
import pandas as pd

# '이직 여부' 컬럼을 기반으로 'is_job_change' 컬럼 생성 ('1'은 비이직자, '2'는 이직자)
df1['is_job_change'] = df1['이직여부'].apply(lambda x: 1 if x == 2 else 0)

# 그룹별 이직률 계산 함수
def calculate_job_change_rate(df1, group_col):
    grouped_data = df1.groupby(group_col)
    grouped_stats = grouped_data['is_job_change'].agg(['sum', 'count']).reset_index()
    grouped_stats['job_change_rate'] = grouped_stats['sum'] / grouped_stats['count']
    return grouped_stats[[group_col, 'job_change_rate']]

# 각 변수별 이직률 데이터프레임 생성
majorcat_df1 = calculate_job_change_rate(df1, 'majorcat')  # 전공 계열별 이직률
school_df1 = calculate_job_change_rate(df1, 'school')      # 학교 유형별 이직률
area_df1 = calculate_job_change_rate(df1, 'area')          # 지역별 이직률
sex_df1 = calculate_job_change_rate(df1, 'sex')            # 성별별 이직률

# %%
majorcat_df1
# Out:
#    majorcat  job_change_rate
# 0         1         0.735596
# 1         2         0.763135
# 2         3         0.850064
# 3         4         0.797176
# 4         5         0.799489
# 5         6         0.813671
# 6         7         0.762522

# %%
school_df1
# Out:
#    school  job_change_rate
# 0       1         0.815676
# 1       2         0.774225
# 2       3         0.954315

# %%
area_df1
# Out:
#     area  job_change_rate
# 0      1         0.781124
# 1      2         0.761955
# 2      3         0.772043
# 3      4         0.832765
# 4      5         0.752412
# 5      6         0.783133
# 6      7         0.834395
# 7      8         0.768657
# 8      9         0.772812
# 9     10         0.816364
# 10    11         0.771084
# 11    12         0.799622
# 12    13         0.825083
# 13    14         0.827670
# 14    15         0.789279
# 15    16         0.766990
# 16    17         0.715789

# %%
sex_df1
# Out:
#    sex  job_change_rate
# 0    1         0.800442
# 1    2         0.764778

# %% [markdown]
# ### 전공에 따른 이직률

# %%
import seaborn as sns

sns.set_theme(style="whitegrid") 
sns.barplot(x="majorcat", y="job_change_rate", data=majorcat_df1)
# Out:
# <Axes: xlabel='majorcat', ylabel='job_change_rate'>

# %% [markdown]
# 전공에 따른 이직률은 교육 전공(전공계열3)이 가장 높고 인문 전공(전공계열1)이 가장 낮다.

# %% [markdown]
# ### 학교 유형에 따른 이직률

# %%
import seaborn as sns

sns.set_theme(style="whitegrid") 
sns.barplot(x="school", y="job_change_rate", data=school_df1)
# Out:
# <Axes: xlabel='school', ylabel='job_change_rate'>

# %% [markdown]
# 학교 유형에 따른 이직률은 교육대가 가장 높고 4년제가 가장 낮다.

# %%
sns.set_theme(style="whitegrid") 
sns.barplot(x="area", y="job_change_rate", data=area_df1)
# Out:
# <Axes: xlabel='area', ylabel='job_change_rate'>

# %%
sns.set_theme(style="whitegrid") 
sns.barplot(x="sex", y="job_change_rate", data=sex_df1)
# Out:
# <Axes: xlabel='sex', ylabel='job_change_rate'>

# %% [markdown]
# 성별에 따른 이직률은 남성이 여성보다 높다.

# %% [markdown]
# ### 전공계열, 학교유형, 성별에 따른 이직률

# %%
import pandas as pd

# '이직 여부' 컬럼을 기반으로 'is_job_change' 컬럼 생성 ('1'은 비이직자, '2'는 이직자)
df1['is_job_change'] = df1['이직여부'].apply(lambda x: 1 if x == 2 else 0)

# majorcat, school, sex를 기준으로 그룹화하여 이직률 계산
grouped_data = df1.groupby(['majorcat', 'school', 'sex'])
grouped_stats = grouped_data['is_job_change'].agg(['sum', 'count']).reset_index()

# 이직률 계산
grouped_stats['job_change_rate'] = grouped_stats['sum'] / grouped_stats['count']

majorcat_school_sex_df1 = grouped_stats[['majorcat', 'school', 'sex', 'job_change_rate']]
majorcat_school_sex_df1
# Out:
#     majorcat  school  sex  job_change_rate
# 0          1       1    1         0.805556
# 1          1       1    2         0.830508
# 2          1       2    1         0.781250
# 3          1       2    2         0.687879
# 4          2       1    1         0.845238
# 5          2       1    2         0.813636
# 6          2       2    1         0.778793
# 7          2       2    2         0.710723
# 8          3       1    1         0.750000
# 9          3       1    2         0.835616
# 10         3       2    1         0.754717
# 11         3       2    2         0.855219
# 12         3       3    1         0.924528
# 13         3       3    2         0.965278
# 14         4       1    1         0.822581
# 15         4       1    2         0.778761
# 16         4       2    1         0.796280
# 17         4       2    2         0.771127
# 18         5       1    1         0.855932
# 19         5       1    2         0.797872
# 20         5       2    1         0.812500
# ...

# %% [markdown]
# ### 전공계열과 성별별 이직률

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm 

font_path = 'C:/Windows/Fonts/malgun.ttf'  
font_prop = fm.FontProperties(fname=font_path, size=14)
plt.rc('font', family=font_prop.get_name())
plt.rcParams['axes.unicode_minus'] = False  

plt.figure(figsize=(12, 6))
sns.barplot(data=majorcat_school_sex_df1, x='majorcat', y='job_change_rate', hue='sex')
plt.title('전공 계열과 성별별 이직률')
plt.show()

# %% [markdown]
# 이직률은 교육 전공 여성이 가장 높고 인문 전공 여성이 가장 낮다.

# %% [markdown]
# ### 학교 유형과 성별에 따른 이직률

# %%
plt.figure(figsize=(10, 6))
heatmap_data = majorcat_school_sex_df1.pivot_table(index='school', columns='sex', values='job_change_rate')
sns.heatmap(heatmap_data, annot=True, fmt='.2f', cmap='Blues', cbar_kws={'label': '이직률'})
plt.title('학교 유형과 성별에 따른 이직률 히트맵')
plt.xlabel('성별')
plt.ylabel('학교 유형')
plt.show()

# %% [markdown]
# 이직률은 교육대를 졸업한 여성이 가장 높고 4년제 졸업 여성이 가장 낮다.

# %%
# 학교 유형과 전공 계열별 이직률 바 차트

school_majorcat_df1 = grouped_stats[['school', 'majorcat', 'job_change_rate']]
plt.figure(figsize=(12, 6))
sns.barplot(data=school_majorcat_df1, x='school', y='job_change_rate', hue='majorcat')

plt.title('학교 유형과 전공 계열별 이직률')
plt.xlabel('학교 유형')
plt.ylabel('이직률')
plt.show()

# %% [markdown]
# 2~3년제에서는 예체능 전공이 가장 이직률이 낮고 자연 전공이 가장 이직률이 높다.
# 4년제에서는 인문 전공이 가장 이직률이 낮고 의약 전공이 가장 이직률이 높다.
# 교육대는 데이터가 불충분하므로 비교하기 어렵다.

# %% [markdown]
# ## 취업 현황 분석

# %%
# 전공별 산업군 분포 계산

industry_distribution = df1.pivot_table(index='majorcat', columns='industry', values='job', aggfunc='count', fill_value=0)
industry_distribution_percentage = industry_distribution.div(industry_distribution.sum(axis=1), axis=0) * 100  

plt.figure(figsize=(14, 8))
industry_distribution_percentage.plot(kind='bar', stacked=True)
plt.title('전공 계열별 산업군 분포')
plt.xlabel('전공 계열')
plt.ylabel('진출 비율 (%)')
plt.legend(title='산업군', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
#전공별 직무 유형 분포 계산
job_distribution = df1.pivot_table(index='majorcat', columns='job', values='industry', aggfunc='count', fill_value=0)
job_distribution_percentage = job_distribution.div(job_distribution.sum(axis=1), axis=0) * 100  # 비율로 변환

plt.figure(figsize=(14, 8))
job_distribution_percentage.plot(kind='bar', stacked=True)
plt.title('전공 계열별 직무 유형(job) 분포')
plt.xlabel('전공 계열')
plt.ylabel('진출 비율 (%)')
plt.legend(title='직무 유형', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 만족도 통계

# %%
satis_df1 = ['a126', 'a127', 'a128', 'a129', 'a130', 'a131', 'a132', 'a133', 'a134', 'a135', 'a136', 'a137', 'a138', 'a139', 'a140', 'a141']

# 전공 계열별 평균 만족도 계산
major_satis = df1.groupby('majorcat')[satis_df1].mean().reset_index()

# 산업군별 평균 만족도 계산
industry_satis = df1.groupby('industry')[satis_df1].mean().reset_index()

# 직무 유형별 평균 만족도 계산
job_satis = df1.groupby('job')[satis_df1].mean().reset_index()

# %%
major_satis
# Out:
#    majorcat      a126      a127      a128      a129      a130      a131  \
# 0         1  3.172849  3.710339  3.768745  3.887924  3.737174  3.532755
# 1         2  3.268827  3.812609  3.746060  3.892732  3.765762  3.582312
# 2         3  3.510801  4.115629  4.069886  4.168996  4.149936  3.941550
# 3         4  3.371165  3.885963  3.811567  3.888678  3.755091  3.704589
# 4         5  3.280332  3.787995  3.835249  3.869732  3.708174  3.741379
# 5         6  3.271224  3.883131  3.750827  3.770673  3.535832  3.587652
# 6         7  3.043178  3.443869  3.740069  3.770294  3.573402  3.613126
#
#        a132      a133      a134      a135      a136      a137      a138  \
# 0  3.860300  3.524073  3.203631  3.655091  3.727703  3.688240  3.723757
# 1  3.811734  3.609895  3.273643  3.686077  3.697023  3.711471  3.706655
# 2  4.038119  3.991105  3.560356  4.005083  4.000000  4.034307  4.091487
# 3  3.902525  3.627206  3.410806  3.724409  3.775455  3.732555  3.761336
# ...

# %%
industry_satis
# Out:
#     industry      a126      a127      a128      a129      a130      a131  \
# 0         -1  3.000000  3.333333  3.222222  3.666667  3.777778  3.888889
# 1          1  3.296296  3.802469  3.864198  3.654321  3.419753  3.827160
# 2          2  3.000000  5.000000  3.000000  2.000000  4.000000  4.000000
# 3          3  3.409967  3.856135  3.702868  3.756465  3.683122  3.559003
# 4          4  4.078125  4.312500  3.968750  4.085938  4.250000  3.867188
# 5          5  3.370370  4.037037  3.703704  3.648148  3.796296  3.666667
# 6          6  3.362110  3.750600  3.707434  3.642686  3.412470  3.693046
# 7          7  3.260000  3.740000  3.680000  3.829412  3.718824  3.457647
# 8          8  3.406832  4.090062  3.801242  3.732919  3.816770  3.487578
# 9          9  3.213256  3.648415  3.763689  3.870317  3.544669  3.550432
# 10        10  3.143695  3.726295  3.846530  3.994135  3.732160  3.672532
# 11        11  3.625551  4.033040  3.790749  4.055066  3.953744  3.674009
# ...

# %%
job_satis
# Out:
#     job      a126      a127      a128      a129      a130      a131      a132  \
# 0    -1  3.400000  3.733333  3.866667  4.000000  3.933333  3.933333  3.800000
# 1     1  3.264162  3.819783  3.690637  3.894922  3.781920  3.508072  3.836513
# 2     2  3.294263  3.848796  3.868626  3.952904  3.730524  3.818697  3.906161
# 3     3  3.433071  3.945538  4.003281  4.029528  4.016404  3.931102  3.990157
# 4     4  3.221302  3.889941  3.751479  3.768047  3.508876  3.542012  3.743195
# 5     5  2.927126  3.412955  3.824899  3.798583  3.510121  3.640688  3.785425
# 6     6  3.295673  3.673077  3.826923  3.848558  3.612981  3.579327  3.769231
# 7     7  3.370529  3.761087  3.719599  3.806867  3.668097  3.510730  3.746781
# 8     8  3.755556  3.533333  3.733333  3.622222  3.822222  3.755556  4.000000
# 9     9  3.474785  3.917589  3.747847  3.676507  3.753998  3.587946  3.847478
# 10   10  3.302632  3.815789  3.907895  3.697368  3.421053  3.894737  3.776316
#
# ...

# %% [markdown]
# ### 전공 계열별 평균 만족도

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
bar_width = 0.075  
x = np.arange(len(major_satis['majorcat'])) * 1.5  


for i, column in enumerate(satis_df1):
    plt.bar(x + i * bar_width, major_satis[column], width=bar_width, label=column)

plt.title('전공 계열별 평균 만족도')
plt.xlabel('전공 계열')
plt.ylabel('평균 만족도')
plt.xticks(x + bar_width * (len(satis_df1) - 1) / 2, major_satis['majorcat'], rotation=45, ha='right')  # x축 레이블 설정
plt.legend(title='만족도 항목', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# 'majorcat' 열을 인덱스로 설정하고 만족도 항목만 선택
heatmap_data = major_satis.set_index('majorcat').T  # 전치하여 만족도 항목이 행이 되도록

# 히트맵 생성
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label': '평균 만족도'})
plt.title('전공 계열별 평균 만족도')
plt.xlabel('전공 계열')
plt.ylabel('만족도 항목')
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()
plt.show()

# %% [markdown]
# 전공 계열 중 '교육'전공 계열이 평균적으로 가장 높은 만족도를 보였다.

# %% [markdown]
# ### 산업군별 만족도 바 차트

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


num_columns = len(industry_satis.columns) - 1  
colors = plt.cm.viridis(np.linspace(0, 1, num_columns))  

# 산업군별 평균 만족도를 바 차트로 시각화
plt.figure(figsize=(14, 8))

bar_width = 0.05 
x = np.arange(len(industry_satis['industry']))  

for i, column in enumerate(industry_satis.columns[1:]):  
    plt.bar(x + i * bar_width, industry_satis[column], 
            width=bar_width, label=column, color=colors[i])

plt.title('산업군별 평균 만족도')
plt.xlabel('산업군')
plt.ylabel('평균 만족도')
plt.xticks(x + bar_width * (num_columns - 1) / 2, 
           industry_satis['industry'], rotation=45) 
plt.legend(title='만족도 항목', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# 'industry' 열을 인덱스로 설정하고 만족도 항목만 선택
heatmap_data = industry_satis.set_index('industry').T  # 전치하여 만족도 항목이 행이 되도록

# 히트맵 생성
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label': '평균 만족도'})
plt.title('산업군별 평균 만족도')
plt.xlabel('산업군')
plt.ylabel('만족도 항목')
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 직무 유형별 평균 만족도

# %%
plt.figure(figsize=(14, 8))
job_satis.plot(x='job', kind='bar', stacked=False, width=0.9)
plt.title('직무 유형별 평균 만족도')
plt.xlabel('직무 유형')
plt.ylabel('평균 만족도')
plt.xticks(rotation=45)
plt.legend(title='만족도 항목', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
heatmap_data = job_satis.set_index('job').T  # 전치하여 만족도 항목이 행이 되도록

# 히트맵 생성
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label': '평균 만족도'})
plt.title('직무 유형별 평균 만족도 히트맵')
plt.xlabel('직무 유형')
plt.ylabel('만족도 항목')
plt.xticks(rotation=45)  # x축 레이블 회전
plt.tight_layout()
plt.show()

# %% [markdown]
# 예술/디자인/방송/스포츠직(job5)이 임금과 인사제도 문항에서 가장 낮은 만족도의 응답이 나왔다.

# %% [markdown]
# ### 전공 계열과 만족도 히트맵

# %%
plt.figure(figsize=(12, 8))
satis_heatmap = major_satis.set_index('majorcat').T  # 전치하여 만족도 항목을 행으로
sns.heatmap(satis_heatmap, annot=True, cmap='coolwarm', cbar_kws={'label': '평균 만족도'})
plt.title('전공 계열별 만족도 히트맵')
plt.xlabel('전공 계열')
plt.ylabel('만족도 항목')
plt.tight_layout()
plt.show()

# %% [markdown]
# 대부분의 항목에서 높은 만족도를 보였던 교육 계열에서 가장 불만족스러웠던 문항은 '임금'(a126)과 '인사체계(승진제도)'(a134)인 것으로 나타났다.
# 이 두 문항은 대부분의 전공계열에서 낮은 만족도를 보였다.
# 가장 낮은 평균만족도를 보인 것은 예체능 계열의 '임금'이었다.
